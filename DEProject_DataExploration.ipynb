# %%
import pandas as pd

project_df = pd.read_csv('/content/project_dataset.csv')
project_df.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
project_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %%
project_df.columns
# Out:
# Index(['name', 'author', 'narrator', 'time', 'releasedate', 'language',
#        'stars', 'price'],
#       dtype='object')

# %%
project_df['name'] #Series
project_df[['name', 'author', 'narrator']] #Dataframe
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator
# 0          Narratedby:BillLobely
# 1       Narratedby:RobbieDaymond
# 2          Narratedby:DanRussell
# 3      Narratedby:SoneelaNankani
# 4      Narratedby:JesseBernstein
# ...                          ...
# 87484    Narratedby:ChrisStewart
# 87485      Narratedby:RobertFass
# 87486       Narratedby:FloGibson
# 87487     Narratedby:AntonLesser
# 87488     Narratedby:FleetCooper
#
# [87489 rows x 3 columns]

# %%
#Data Cleaning - name cleaning
import re

def name_cleaning(name):
  name = name.replace('Writtenby:', '')
  name = name.replace('Narratedby:', '')
  name = re.sub('([A-Z])', r' \1', name)
  return name

# %%
#author name cleaning
project_df.author = project_df['author'].apply(name_cleaning)

# %%
#narrator name cleaning
project_df.narrator = project_df['narrator'].apply(name_cleaning)

# %%
project_df.columns
# Out:
# Index(['name', 'author', 'narrator', 'time', 'releasedate', 'language',
#        'stars', 'price'],
#       dtype='object')

# %%
project_df.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins    04-08-08  English
# 1    Robbie Daymond   13 hrs and 8 mins    01-05-18  English
# 2       Dan Russell    2 hrs and 3 mins    06-11-20  English
# 3   Soneela Nankani  11 hrs and 16 mins    05-10-21  English
# 4   Jesse Bernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
#extract total minutes from time

def extract_mins(time):
  mins = 0
  if 'hr' in time.lower():
    time_list = [int(s) for s in time.split() if s.isdigit()]
    if len(time_list) == 1:
      mins = time_list[0]*60
    elif len(time_list)==2:
      mins = (time_list[0]*60) + time_list[1]
    else:
      mins = 0
  else:
    if 'min' in time.lower():
      time_list = [int(s) for s in time.split() if s.isdigit()]
      if len(time_list) == 1:
        mins = time_list[0]
      else:
        mins = 0
  return mins

# %%
project_df['minutes'] = project_df['time'].apply(extract_mins)

# %%
project_df.head()
#project_df = project_df.drop (['minutes'], axis =1)

min = project_df['time'] == 'Less than 1 minute'
project_df[min]
# Out:
#                                         name                author  \
# 1401                  The Story of Ice Cream   Stacy Taus- Bolstad
# 1403                       The Story of Salt           Lisa Owings
# 1404                       The Story of Milk   Stacy Taus- Bolstad
# 1408                   The Story of an Apple   Stacy Taus- Bolstad
# 1409                      We Like the Summer          Katie Peters
# ...                                      ...                   ...
# 87171  第二十五話サン・ミシェルのいいカフェ：ぼくの旅の手帖〜または珈琲のある風景                  森本哲郎
# 87175         第九話オラン最後の夕べ：ぼくの旅の手帖〜または珈琲のある風景                  森本哲郎
# 87176        第一話リューベックの追憶:ぼくの旅の手帖〜または珈琲のある風景                  森本哲郎
# 87180         第七話バグダードの茶屋:ぼくの旅の手帖〜または珈琲のある風景                  森本哲郎
# 87192        第十八話バンコックの憂鬱：ぼくの旅の手帖〜または珈琲のある風景                  森本哲郎
#
#                         narrator                time releasedate  language  \
# 1401    Book Buddy Digital Media  Less than 1 minute    01-01-21   English
# 1403    Book Buddy Digital Media  Less than 1 minute    01-01-21   English
# 1404    Book Buddy Digital Media  Less than 1 minute    01-01-21   English
# 1408    Book Buddy Digital Media  Less than 1 minute    01-01-21   English
# 1409    Book Buddy Digital Media  Less than 1 minute    01-01-21   English
# ...                          ...                 ...         ...       ...
# 87171                      小野田英一  Less than 1 minute    20-11-15  japanese
# 87175                      小野田英一  Less than 1 minute    19-11-15  japanese
# 87176                      小野田英一  Less than 1 minute    23-07-15  japanese
# 87180                      小野田英一  Less than 1 minute    13-07-15  japanese
# 87192                      小野田英一  Less than 1 minute    19-11-15  japanese
#
#                stars   price  minutes
# 1401   Not rated yet  164.00        1
# 1403   Not rated yet  164.00        1
# 1404   Not rated yet  164.00        1
# 1408   Not rated yet  164.00        1
# 1409   Not rated yet  164.00        1
# ...              ...     ...      ...
# 87171  Not rated yet  139.00        1
# 87175  Not rated yet  139.00        1
# 87176  Not rated yet  139.00        1
# 87180  Not rated yet  139.00        1
# 87192  Not rated yet  139.00        1
#
# [61 rows x 9 columns]

# %%
#Date Validation, format: dd-mm-yy
#Note: Year is not validated because of ambiguity

def check_date(date):
  date_list = [int(s) for s in date.split('-') if s.isdigit()]
  if len(date_list) == 3:
    if date_list[1] < 13:
        if date_list[1] in [1,3,5,7,8,10,12] and date_list[0] < 32:
          return True
        elif date_list[1] == 2:
          if date_list[2]%4==0 and date_list[0] < 30:
            return True
          elif date_list[0] < 29:
            return True
        elif date_list[1] in [4,6,9,11] and date_list[0] < 31:
          return True
  return False

# %%
project_df['date_valid'] = project_df['releasedate'].apply(check_date)

# %%
project_df.head()

date_invalid = project_df['date_valid'] == False
project_df[date_invalid] #All dates are valid

project_df = project_df.drop (['date_valid'], axis =1)

# %%
#Change Date Format
project_df["releasedate"] = pd.to_datetime(project_df["releasedate"], format='%d-%m-%y')
project_df.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2       Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars   price  minutes
# 0     5 out of 5 stars34 ratings  468.00      140
# 1   4.5 out of 5 stars41 ratings  820.00      788
# 2   4.5 out of 5 stars38 ratings  410.00      123
# 3   4.5 out of 5 stars12 ratings  615.00      676
# 4  4.5 out of 5 stars181 ratings  820.00      600

# %%
#Extract ratings and no_of_ratings
project_df[['rating','number_of_ratings']] = project_df['stars'].str.split('stars', 1, expand=True)
project_df.head()
# Out:
# <ipython-input-31-44caef568bc4>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   project_df[['rating','number_of_ratings']] = project_df['stars'].str.split('stars', 1, expand=True)
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2       Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars  price  minutes         rating  \
# 0     5 out of 5 stars34 ratings  468.0      140    5 out of 5
# 1   4.5 out of 5 stars41 ratings  820.0      788  4.5 out of 5
# 2   4.5 out of 5 stars38 ratings  410.0      123  4.5 out of 5
# 3   4.5 out of 5 stars12 ratings  615.0      676  4.5 out of 5
# 4  4.5 out of 5 stars181 ratings  820.0      600  4.5 out of 5
#
#   number_of_ratings
# 0        34 ratings
# 1        41 ratings
# 2        38 ratings
# 3        12 ratings
# 4       181 ratings

# %%
no_rating = project_df['stars'] == 'Not rated yet'
project_df[no_rating]
# Out:
#                                                     name            author  \
# 34     14 Short Stories Bundle for Kids: Adventure, S...   Nayomi Phillips
# 50                              A Bear Called Paddington      Michael Bond
# 51                Gregor and the Curse of the Warmbloods   Suzanne Collins
# 61                                     Across the Desert     Dusti Bowling
# 62                     Unicorn Academy: Aisha and Silver       Julie Sykes
# ...                                                  ...               ...
# 87484                          Last Days of the Bus Club     Chris Stewart
# 87485                                           The Alps   Stephen O' Shea
# 87486                               The Innocents Abroad        Mark Twain
# 87487                              A Sentimental Journey   Laurence Sterne
# 87488                                             Havana    Mark Kurlansky
#
#                                              narrator               time  \
# 34      Monica Rachelle, Jim D. Johnston, Katie Otten  3 hrs and 13 mins
# 50                                        Stephen Fry  2 hrs and 39 mins
# 51                                       Paul Boehmer  7 hrs and 47 mins
# 61                                     Stacy Gonzalez  6 hrs and 13 mins
# 62                                   Kristin Atherton   1 hr and 34 mins
# ...                                               ...                ...
# 87484                                   Chris Stewart  7 hrs and 34 mins
# 87485                                     Robert Fass  10 hrs and 7 mins
# 87486                                      Flo Gibson  19 hrs and 4 mins
# 87487                                    Anton Lesser   4 hrs and 8 mins
# 87488                                    Fleet Cooper    6 hrs and 1 min
#
#       releasedate language          stars   price  minutes  rating  \
# 34     2019-01-22  English  Not rated yet   501.0      193     0.0
# 50     2008-06-24  English  Not rated yet   266.0      159     0.0
# 51     2004-12-26  English  Not rated yet  1005.0      467     0.0
# 61     2022-03-29  English  Not rated yet   703.0      373     0.0
# 62     2022-03-10  English  Not rated yet   266.0       94     0.0
# ...           ...      ...            ...     ...      ...     ...
# 87484  2017-03-09  English  Not rated yet   596.0      454     0.0
# 87485  2017-02-21  English  Not rated yet   820.0      607     0.0
# 87486  2016-12-30  English  Not rated yet   938.0     1144     0.0
# 87487  2011-02-23  English  Not rated yet   680.0      248     0.0
# 87488  2017-03-07  English  Not rated yet   569.0      361     0.0
#
#       number_of_ratings
# 34                 None
# 50                 None
# 51                 None
# 61                 None
# 62                 None
# ...                 ...
# 87484              None
# 87485              None
# 87486              None
# 87487              None
# 87488              None
#
# [72417 rows x 11 columns]

# %%
project_df.rating = project_df['rating'].str.extract('([-+]?\d*\.?\d+)').astype('float').fillna(0)
project_df.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2       Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars  price  minutes  rating number_of_ratings
# 0     5 out of 5 stars34 ratings  468.0      140     5.0        34 ratings
# 1   4.5 out of 5 stars41 ratings  820.0      788     4.5        41 ratings
# 2   4.5 out of 5 stars38 ratings  410.0      123     4.5        38 ratings
# 3   4.5 out of 5 stars12 ratings  615.0      676     4.5        12 ratings
# 4  4.5 out of 5 stars181 ratings  820.0      600     4.5       181 ratings

# %%
project_df.number_of_ratings = project_df['number_of_ratings'].str.extract('(\d+)').astype('float')
project_df.number_of_ratings = project_df['number_of_ratings'].fillna(0).astype('int')
project_df.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2       Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars   price  minutes  rating  number_of_ratings
# 0     5 out of 5 stars34 ratings  468.00      140       5                 34
# 1   4.5 out of 5 stars41 ratings  820.00      788       4                 41
# 2   4.5 out of 5 stars38 ratings  410.00      123       4                 38
# 3   4.5 out of 5 stars12 ratings  615.00      676       4                 12
# 4  4.5 out of 5 stars181 ratings  820.00      600       4                181

# %%
project_df.price = project_df['price'].str.replace(',', '').str.extract(r'(\d+.\d+)').astype('float')
project_df.price = project_df['price'].fillna(0)
project_df.head()
# Out:
#                                          name             author  \
# 0                  Geronimo Stilton #11 & #12   Geronimo Stilton
# 1                            The Burning Maze       Rick Riordan
# 2                                The Deep End        Jeff Kinney
# 3                        Daughter of the Deep       Rick Riordan
# 4  The Lightning Thief: Percy Jackson, Book 1       Rick Riordan
#
#            narrator                time releasedate language  \
# 0       Bill Lobely   2 hrs and 20 mins  2008-08-04  English
# 1    Robbie Daymond   13 hrs and 8 mins  2018-05-01  English
# 2       Dan Russell    2 hrs and 3 mins  2020-11-06  English
# 3   Soneela Nankani  11 hrs and 16 mins  2021-10-05  English
# 4   Jesse Bernstein              10 hrs  2010-01-13  English
#
#                            stars  price  minutes  rating  number_of_ratings
# 0     5 out of 5 stars34 ratings  468.0      140       5                 34
# 1   4.5 out of 5 stars41 ratings  820.0      788       4                 41
# 2   4.5 out of 5 stars38 ratings  410.0      123       4                 38
# 3   4.5 out of 5 stars12 ratings  615.0      676       4                 12
# 4  4.5 out of 5 stars181 ratings  820.0      600       4                181

# %%
project_df.to_csv('InProcess_output.csv', index = False)
